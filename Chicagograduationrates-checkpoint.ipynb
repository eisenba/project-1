# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\asimg\\Downloads\\CITY_OF_CHICAGO_SD_299_working.csv")

# %%
df.head()
# Out:
#      Domain  Year  English Learners (%)  With IEPs (%)  Low Income (%)  \
# 0  District  2019                  19.4           14.1            77.9
# 1  District  2018                  19.3           14.1            82.6
# 2  District  2017                  17.7           11.0            83.1
# 3  District  2016                  17.8           14.4            83.9
# 4  District  2015                  17.8           14.0            86.9
#
#    Homeless (%) Parental Involvement (%)  Attendance (%)  Mobility (%)  \
# 0           3.5                        -            93.2          10.1
# 1           4.0                     77.1            93.3          10.5
# 2           4.1                     76.9            93.2          10.8
# 3           4.3                     79.7            93.8          19.2
# 4           4.6                       81            93.5          17.0
#
#    Chronic Truants (%)  ...  EL Long Term Students (%)  Total Enrollment (N)  \
# ...

# %%
df_district = df[df["Domain"] == "District"]

# %%
yr = [2017, 2018]
df_district = df_district[df_district["Year"].isin(yr)]

# %%
# keep only the columns that we are interested in
# Domain, Year, "4 Yr Graduation Rate (%)"
keep_columns = ["Domain", "Year", "4 Yr Graduation Rate (%)", "Total Enrollment (N)"]
df_district = df_district[keep_columns]

# %%
df_district
# Out:
#      Domain  Year  4 Yr Graduation Rate (%)  Total Enrollment (N)
# 1  District  2018                      76.3                372214
# 2  District  2017                      82.3                382929

# %%
df_district.to_csv("c:\\Users\\asimg\Documents\ChicagoGradutionFiltered.csv")
